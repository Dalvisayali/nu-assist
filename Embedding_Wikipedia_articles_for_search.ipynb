# %% [markdown]
# # Embedding Wikipedia articles for search
#
# This notebook shows how we prepared a dataset of Wikipedia articles for search, used in [Question_answering_using_embeddings.ipynb](Question_answering_using_embeddings.ipynb).
#
# Procedure:
#
# 0. Prerequisites: Import libraries, set API key (if needed)
# 1. Collect: We download a few hundred Wikipedia articles about the 2022 Olympics
# 2. Chunk: Documents are split into short, semi-self-contained sections to be embedded
# 3. Embed: Each section is embedded with the OpenAI API
# 4. Store: Embeddings are saved in a CSV file (for large datasets, use a vector database)

# %% [markdown]
# ## 0. Prerequisites
#
# ### Import libraries

# %%
# imports
import mwclient  # for downloading example Wikipedia articles
import mwparserfromhell  # for splitting Wikipedia articles into sections
import openai  # for generating embeddings
import pandas as pd  # for DataFrames to store article sections and embeddings
import re  # for cutting <ref> links out of Wikipedia articles
import tiktoken  # for counting tokens

# %% [markdown]
# Install any missing libraries with `pip install` in your terminal. E.g.,
#
# ```zsh
# pip install openai
# ```
#
# (You can also do this in a notebook cell with `!pip install openai`.)
#
# If you install any libraries, be sure to restart the notebook kernel.

# %% [markdown]
# ### Set API key (if needed)
#
# Note that the OpenAI library will try to read your API key from the `OPENAI_API_KEY` environment variable. If you haven't already, set this environment variable by following [these instructions](https://help.openai.com/en/articles/5112595-best-practices-for-api-key-safety).

# %% [markdown]
# ## 1. Collect documents
#
# In this example, we'll download a few hundred Wikipedia articles related to the 2022 Winter Olympics.

# %%
# get Wikipedia pages about the 2022 Winter Olympics

CATEGORY_TITLE = "Category:2022 Winter Olympics"
WIKI_SITE = "en.wikipedia.org"


def titles_from_category(
    category: mwclient.listing.Category, max_depth: int
) -> set[str]:
    """Return a set of page titles in a given Wiki category and its subcategories."""
    titles = set()
    for cm in category.members():
        if type(cm) == mwclient.page.Page:
            # ^type() used instead of isinstance() to catch match w/ no inheritance
            titles.add(cm.name)
        elif isinstance(cm, mwclient.listing.Category) and max_depth > 0:
            deeper_titles = titles_from_category(cm, max_depth=max_depth - 1)
            titles.update(deeper_titles)
    return titles


site = mwclient.Site(WIKI_SITE)
category_page = site.pages[CATEGORY_TITLE]
titles = titles_from_category(category_page, max_depth=1)
# ^note: max_depth=1 means we go one level deep in the category tree
print(f"Found {len(titles)} article titles in {CATEGORY_TITLE}.")
# Out:
# Found 731 article titles in Category:2022 Winter Olympics.

# %%
titles
# Out:
# {'128th IOC Session',
#  '2020–21 figure skating season',
#  '2021 Canadian Olympic Curling Trials',
#  '2021 Olympic Qualification Event – Curling',
#  '2021 Pre-Olympic Qualification Event',
#  '2022 Canadian Mixed Doubles Curling Olympic Trials',
#  '2022 Winter Olympics',
#  '2022 Winter Olympics Parade of Nations',
#  '2022 Winter Olympics closing ceremony',
#  '2022 Winter Olympics closing ceremony flag bearers',
#  '2022 Winter Olympics marketing',
#  '2022 Winter Olympics medal table',
#  '2022 Winter Olympics opening ceremony',
#  '2022 Winter Olympics torch relay',
#  '2022 Winter Paralympics',
#  '2022 Winter Paralympics Parade of Nations',
#  '2022 Winter Paralympics closing ceremony',
#  '2022 Winter Paralympics medal table',
#  '2022 Winter Paralympics opening ceremony',
#  '2022 Winter Paralympics torch relay',
#  'Abbey Murphy',
#  'Abby Roque',
#  'Abigail Strate',
#  'Adrián Holešinský',
#  'Agnes Knochenhauer',
#  'Akito Watabe',
#  'Albania at the 2022 Winter Olympics',
#  'Aleksander Aamodt Kilde',
#  'Aleksandr Galliamov',
#  'Aleksey Chervotkin',
#  'Alessandro Hämmerle',
#  'Alex Cavallini',
#  'Alex Ferreira',
#  'Alex Fiva',
#  'Alex Hall (skier)',
#  'Alexa Knierim',
#  'Alexander Bolshunov',
#  'Alexander Loginov (biathlon)',
#  'Alexander Nikishin',
#  'Alexander Samonov',
#  'Alexander Schmid',
#  'Alexander Schüller',
#  'Alexander Terentyev',
#  'Alexander Yelesin',
#  'Alexandra Burghardt',
#  'Alexandra Carpenter',
#  'Alexandra Trusova',
#  'Alexandria Loutitt',
#  'Almaty bid for the 2022 Winter Olympics',
#  'Almida de Val',
#  'Alpine skiing at the 2022 Winter Olympics',
#  'Alpine skiing at the 2022 Winter Olympics – Qualification',
#  'Amanda Kessel',
#  'American Samoa at the 2022 Winter Olympics',
#  'Amos Mosaner',
#  'Anastasia Mishina',
#  'Anastasia Smirnova (freestyle skier)',
#  'Anaïs Chevalier-Bouchet',
#  'Andorra at the 2022 Winter Olympics',
#  'Andrea Cassinelli',
#  'Andrei Chibisov',
#  'Angelina Golikova',
#  'Ann-Renée Desbiens',
#  'Anna Berreiter',
#  'Anna Gasser',
#  'Anna Hasselborg',
#  'Anna Shcherbakova',
#  'Anni Keisala',
#  'Antoinette de Jong',
#  'Anton Slepyshev',
#  'Anton Smolski',
#  'Argentina at the 2022 Winter Olympics',
#  'Arianna Fontana',
#  'Arianna Valcepina',
#  'Armenia at the 2022 Winter Olympics',
#  'Arseni Gritsyuk',
#  'Artur Kayumov',
#  'Artyom Minulin',
#  'Ashley Caldwell',
#  'Ashton Bell',
#  'Atte Ohtamaa',
#  'Australia at the 2022 Winter Olympics',
#  'Austria at the 2022 Winter Olympics',
#  'Axel Jungk',
#  'Ayano Sato (speed skater)',
#  'Ayumu Hirano',
#  'Azerbaijan at the 2022 Winter Olympics',
#  'Bart Swings',
#  'Beat Feuz',
#  'Beijing National Aquatics Centre',
#  'Beijing National Indoor Stadium',
#  'Beijing National Speed Skating Oval',
#  'Beijing National Stadium',
#  'Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games',
#  'Beijing bid for the 2022 Winter Olympics',
#  'Belarus at the 2022 Winter Olympics',
#  'Belgium at the 2022 Winter Olympics',
#  'Ben Coakwell',
#  'Benjamin Karl',
#  'Biathlon at the 2022 Winter Olympics',
#  'Biathlon at the 2022 Winter Olympics – Qualification',
#  'Bids for the 2022 Winter Olympics',
#  'Big Air Shougang',
#  'Bing Dwen Dwen and Shuey Rhon Rhon',
#  'Birk Ruud',
#  'Blayre Turnbull',
#  'Bobby Lammie',
#  'Bobsleigh at the 2022 Winter Olympics',
#  'Bobsleigh at the 2022 Winter Olympics – Qualification',
#  'Bolivia at the 2022 Winter Olympics',
#  'Bosnia and Herzegovina at the 2022 Winter Olympics',
#  'Brad Gushue',
#  'Brandon Frazier',
#  'Branislav Konrád',
#  'Brazil at the 2022 Winter Olympics',
#  'Brett Gallant',
#  'Brianna Decker',
#  'Brianne Jenner',
#  'Brittany Bowe',
#  'Bruce Mouat',
#  'Bulgaria at the 2022 Winter Olympics',
#  'COVID-19 cases at the 2022 Winter Olympics and 2022 Winter Paralympics',
#  'Cam Stones',
#  'Canada at the 2022 Winter Olympics',
#  'Candy Bauer',
#  'Capital Indoor Stadium',
#  'Caroline Harvey (ice hockey)',
#  'Casey Dawson',
#  'Cassie Sharpe',
#  'Cayla Barnes',
#  'Cene Prevc',
#  'Cha Min-kyu',
#  'Charles Hamelin',
#  'Chile at the 2022 Winter Olympics',
#  'China National Convention Center',
#  'China at the 2022 Winter Olympics',
#  'Chinami Yoshida',
#  'Chinese Taipei at the 2022 Winter Olympics',
#  'Chloe Kim',
#  'Chloé Trespeuch',
#  'Choi Min-jeong',
#  'Christian Rasp',
#  'Christine de Bruin',
#  'Christoffer Sundgren',
#  'Christoph Hafer',
#  'Christopher Grotheer',
#  'Christopher Lillis',
#  'Christopher Weber',
#  'Chronological summary of the 2022 Winter Olympics',
#  'Chronological summary of the 2022 Winter Paralympics',
#  'Chung Jae-won',
#  'Claire Thompson (ice hockey)',
#  'Clément Noël',
#  'Clément Parisse',
#  'Colby Stevenson',
#  'Colombia at the 2022 Winter Olympics',
#  'Concerns and controversies at the 2022 Winter Olympics',
#  'Constantin Schmid',
#  'Corinne Suter',
#  'Craig Ramsay',
#  'Croatia at the 2022 Winter Olympics',
#  'Cross-country skiing at the 2022 Winter Olympics',
#  'Cross-country skiing at the 2022 Winter Olympics – Qualification',
#  'Curling at the 2022 Winter Olympics',
#  'Curling at the 2022 Winter Olympics – Qualification',
#  'Cyprus at the 2022 Winter Olympics',
#  'Czech Republic at the 2022 Winter Olympics',
#  'Damir Sharipzyanov',
#  'Dani Cameranesi',
#  'Daniel Huber (ski jumper)',
#  'Daniel Magnusson (curler)',
#  'Daniela Maier',
#  'Daniela Ulbing',
#  'Daniil Aldoshkin',
#  'Danil Sadreev',
#  'David Wise (freestyle skier)',
#  'Davide Ghiotto',
#  'Dawid Kubacki',
#  'Deborah Levi',
#  'Denis Spitsov',
#  'Denise Herrmann-Wick',
#  'Denmark at the 2022 Winter Olympics',
#  'Dmitri Voronkov',
#  'Dominik Fischnaller',
#  'Dorothea Wierer',
#  'Ebba Andersson (cross-country skier)',
#  'Ecuador at the 2022 Winter Olympics',
#  'Eduard Latypov',
#  'Egor Yakovlev',
#  'Eileen Gu',
#  'Elana Meyers Taylor',
#  'Elisa Holopainen',
#  'Ella Shelton',
#  'Ella Viitasuo',
#  'Elvira Öberg',
#  'Elīza Tīruma',
#  'Emerance Maschmeyer',
#  'Emery Lehman',
#  'Emil Iversen',
#  'Emilia Vesa',
#  'Emily Clark (ice hockey)',
#  'Emma Aicher',
#  'Emma Maltais',
#  'Eric Frenzel',
#  'Erik Valnes',
#  'Erin Ambrose',
#  'Erin Jackson',
#  'Eritrea at the 2022 Winter Olympics',
#  'Espen Andersen (skier, born 1993)',
#  'Espen Bjørnstad',
#  'Ester Ledecká',
#  'Estonia at the 2022 Winter Olympics',
#  'Ethan Cepuran',
#  'Evan Bates',
#  'Eve Muirhead',
#  'Eveliina Mäkinen',
#  'Evgenia Tarasova',
#  'Evgenii Klimov',
#  'Fabian Wilkens Solheim',
#  'Fabien Claude',
#  'Fan Kexin',
#  'Fanny Smith',
#  'Federica Brignone',
#  'Federico Pellegrino',
#  'Figure skating at the 2022 Winter Olympics',
#  'Figure skating at the 2022 Winter Olympics – Qualification',
#  'Finland at the 2022 Winter Olympics',
#  'Florian Bauer',
#  'France at the 2022 Winter Olympics',
#  'Francesca Lollobrigida',
#  'Francesco Friedrich',
#  'Frans Tuohimaa',
#  'Franziska Preuß',
#  'Freestyle skiing at the 2022 Winter Olympics',
#  'Freestyle skiing at the 2022 Winter Olympics – Qualification',
#  'Frida Karlsson',
#  'Gabriella Papadakis',
#  'Gao Tingyu',
#  'Geoff Walker (curler)',
#  'Georgia at the 2022 Winter Olympics',
#  'Germany at the 2022 Winter Olympics',
#  'Ghana at the 2022 Winter Olympics',
#  'Gloria Kotnik',
#  'Grace Zumwinkle',
#  'Grant Hardie',
#  'Great Britain at the 2022 Winter Olympics',
#  'Greece at the 2022 Winter Olympics',
#  'Guillaume Cizeron',
#  'Hailey Duff',
#  'Haiti at the 2022 Winter Olympics',
#  'Hallgeir Engebråten',
#  'Hammy McMillan Jr.',
#  'Han Cong',
#  'Han Yutong',
#  'Hanna Huskova',
#  'Hanna Öberg',
#  'Hannah Brandt',
#  'Hannah Neise',
#  'Hanne Desmet',
#  'Hannes Björninen',
#  'Hans Christer Holund',
#  'Harri Pesonen',
#  'Harri Säteri',
#  'Hayley Scamurra',
#  'Henrik Harlaut',
#  'Hideaki Nagai',
#  'Hilary Knight (ice hockey)',
#  'Hong Kong at the 2022 Winter Olympics',
#  'Hugo Lapalus',
#  'Hungary at the 2022 Winter Olympics',
#  'Hwang Dae-heon',
#  'Håvard Holmefjord Lorentzen',
#  'Ice River (ski course)',
#  'Ice hockey at the 2022 Winter Olympics',
#  "Ice hockey at the 2022 Winter Olympics – Men's qualification",
#  "Ice hockey at the 2022 Winter Olympics – Women's qualification",
#  'Iceland at the 2022 Winter Olympics',
#  'Iiro Pakarinen',
#  'Iivo Niskanen',
#  'Ikuma Horishima',
#  'Ilya Burov',
#  'India at the 2022 Winter Olympics',
#  'Iran at the 2022 Winter Olympics',
#  'Ireen Wüst',
#  'Ireland at the 2022 Winter Olympics',
#  'Irene Schouten',
#  'Irina Avvakumova',
#  'Irina Kazakevich',
#  'Irma Makhinia',
#  'Isabelle Weidemann',
#  'Israel at the 2022 Winter Olympics',
#  'Italy at the 2022 Winter Olympics',
#  'Ivan Fedotov',
#  'Ivan Yakimushkin',
#  'Ivanie Blondin',
#  'Jaclyn Narracott',
#  'Jaelin Kauf',
#  'Jakara Anthony',
#  'Jamaica at the 2022 Winter Olympics',
#  'James Crawford (alpine skier)',
#  'Jamie Lee Rattray',
#  'Jan Hörl',
#  'Jan Scherrer',
#  'Japan at the 2022 Winter Olympics',
#  'Jenni Hiirikoski',
#  'Jennifer Dodds',
#  'Jenniina Nylund',
#  'Jens Lurås Oftebro',
#  'Jesper Tjäder',
#  'Jesse Compher',
#  'Jessie Diggins',
#  'Jia Zongyang',
#  'Jill Saulnier',
#  'Jincy Dunne',
#  'Jocelyne Larocque',
#  'Joey Mantia',
#  'Johan Clarey',
#  'Johanna Heldin',
#  'Johannes Høsflot Klæbo',
#  'Johannes Lochner',
#  'Johannes Ludwig',
#  'Johannes Strolz',
#  'Johannes Thingnes Bø',
#  'John-Henry Krueger',
#  'Joni Mäki',
#  'Jonna Sundling',
#  'Joonas Nättinen',
#  'Jordan Pierre-Gilles',
#  'Juho Olkinuora',
#  'Jukka Jalonen',
#  'Julia Liikala',
#  'Julia Marino (snowboarder)',
#  'Julia Simon (biathlete)',
#  'Julian Rauchfuß',
#  'Julian Schmid (skier)',
#  'Juraj Slafkovský',
#  'Justin Kripps',
#  'Justin Schoenefeld',
#  'Justine Braisaz-Bouchet',
#  'Jutta Leerdam',
#  'Juuso Hietanen',
#  'Jørgen Graabak',
#  'Kaillie Humphries',
#  'Kamila Valieva',
#  'Kaori Sakamoto',
#  'Karen Chen',
#  'Karl Geiger',
#  'Katharina Hennig',
#  'Katharina Huber',
#  'Katharina Liensberger',
#  'Katharina Schmid',
#  'Katharina Truppe',
#  'Katherine Sauerbrey',
#  'Kazakhstan at the 2022 Winter Olympics',
#  'Kelly Pannek',
#  'Kelly Sildaru',
#  'Kendall Coyne Schofield',
#  'Kerttu Niskanen',
#  'Kim A-lang',
#  'Kim Boutin',
#  'Kim Dong-wook (speed skater)',
#  'Kim Min-seok (speed skater)',
#  'Kimberley Bos',
#  'Kirill Semyonov',
#  'Kjeld Nuis',
#  'Kokomo Murase',
#  'Konstantin Ivliev',
#  'Kosovo at the 2022 Winter Olympics',
#  'Kotomi Ishizaki',
#  'Kraków bid for the 2022 Winter Olympics',
#  'Krista Pärmäkoski',
#  'Kristen Campbell',
#  'Kristers Aparjods',
#  'Kristin Skaslien',
#  'Kristina Reztsova',
#  'Kristián Pospíšil',
#  'Kwak Yoon-gy',
#  'Kyrgyzstan at the 2022 Winter Olympics',
#  'Lara Gut-Behrami',
#  'Latvia at the 2022 Winter Olympics',
#  'Laura Nolte',
#  'Laura Stacey',
#  'Laurent Dubreuil',
#  'Lebanon at the 2022 Winter Olympics',
#  'Lee June-seo',
#  'Lee Seung-hoon',
#  'Lee Stecklein',
#  'Lee Yu-bin',
#  'Lena Dürr',
#  'Leo Komarov',
#  'Lewis Irving',
#  'Li Wenlong (speed skater)',
#  'Libor Hudáček',
#  'Liechtenstein at the 2022 Winter Olympics',
#  'Lindsey Jacobellis',
#  'Linn Persson',
#  'Linus Straßer',
#  'List of 2022 Winter Olympics broadcasters',
#  'List of 2022 Winter Olympics medal winners',
#  'List of 2022 Winter Paralympics medal winners',
#  'List of athletes not attending the 2022 Winter Olympics due to COVID-19 concerns',
#  'Lithuania at the 2022 Winter Olympics',
#  'Lorenz Koller',
#  'Lovro Kos',
#  'Luge at the 2022 Winter Olympics',
#  'Luge at the 2022 Winter Olympics – Qualification',
#  'Lukas Greiderer',
#  'Luxembourg at the 2022 Winter Olympics',
#  'Lviv bid for the 2022 Winter Olympics',
#  'Mackenzie Boyd-Clowes',
#  'Madagascar at the 2022 Winter Olympics',
#  'Maddie Rooney',
#  'Madeleine Egle',
#  'Madison Chock',
#  'Madison Hubbell',
#  'Magnus Nedregotten',
#  'Maja Dahlqvist',
#  'Malaysia at the 2022 Winter Olympics',
#  'Malta at the 2022 Winter Olympics',
#  'Manuel Faißt',
#  'Manuel Fettner',
#  'Marc Kennedy',
#  'Marco Odermatt',
#  'Marek Hrivík',
#  'Marek Ďaloga',
#  'Maria Therese Tviberg',
#  'Mariama Jamanka',
#  'Marie-Philip Poulin',
#  'Marielle Thompson',
#  'Marijke Groenewoud',
#  'Marion Thénault',
#  'Marius Lindvik',
#  'Mark Kondratiuk',
#  'Mark McMorris',
#  'Mark Nichols (curler)',
#  'Marko Anttila',
#  'Marko Daňo',
#  'Markus Eisenbichler',
#  'Markus Granlund',
#  'Marte Olsbu Røiseland',
#  'Martin Gernát',
#  'Martin Marinčin',
#  'Martin Ponsiluoma',
#  'Martina Sáblíková',
#  'Martina Valcepina',
#  'Matej Tomek',
#  'Mathieu Faivre',
#  'Mathilde Gremaud',
#  'Matthew Soukup',
#  'Matthias Mayer',
#  'Matthias Sommer',
#  'Maurice Manificat',
#  'Max Parrot',
#  'Maxim Tsvetkov',
#  'Maxime Laoun',
#  'Meeri Räisänen',
#  'Megan Bozek',
#  'Megan Keller',
#  'Megan Nick',
#  "Meryeta O'Dine",
#  'Mexico at the 2022 Winter Olympics',
#  'Micah Zandee-Hart',
#  'Michael Matt',
#  'Michal Krištof',
#  'Michal Čajkovský',
#  'Michela Moioli',
#  'Michelle Gisin',
#  'Michelle Karvinen',
#  'Miha Fontaine',
#  'Miho Takagi (speed skater)',
#  'Mikaël Kingsbury',
#  'Mikhail Grigorenko',
#  'Mikko Lehtonen (ice hockey, born 1994)',
#  'Mili Smith',
#  'Miloš Kelemen',
#  'Miloš Roman',
#  'Mina Fürst Holtmann',
#  'Minttu Tuominen',
#  'Mirjam Puchner',
#  'Miro Aaltonen',
#  'Misato Komatsubara',
#  'Mislav Rosandić',
#  'Moldova at the 2022 Winter Olympics',
#  'Mona Brorsson',
#  'Monaco at the 2022 Winter Olympics',
#  'Mongolia at the 2022 Winter Olympics',
#  'Mons Røisland',
#  'Montenegro at the 2022 Winter Olympics',
#  'Morocco at the 2022 Winter Olympics',
#  'Mélodie Daoust',
#  'Mārtiņš Bots',
#  'Nadia Delago',
#  'Nana Takagi',
#  'Natalie Geisenberger',
#  'Natalie Spooner',
#  'Natalya Nepryayeva',
#  'Nathan Chen',
#  'Nelli Laitinen',
#  'Netherlands at the 2022 Winter Olympics',
#  'New Zealand at the 2022 Winter Olympics',
#  'Nick Baumgartner',
#  'Nick Goepper',
#  'Nico Porteous',
#  'Nicole Hensley',
#  'Nigeria at the 2022 Winter Olympics',
#  'Nika Križnar',
#  'Nikita Gusev',
#  'Nikita Katsalapov',
#  'Nikita Nesterov',
#  'Niklas Edin',
#  'Niklas Friman',
#  'Niko Ojamäki',
#  'Nils van der Poel',
#  'Noora Tulus',
#  'Nordic combined at the 2022 Winter Olympics',
#  'Nordic combined at the 2022 Winter Olympics – Qualification',
#  'North Macedonia at the 2022 Winter Olympics',
#  'Norway at the 2022 Winter Olympics',
#  'Oleksandr Abramenko',
#  'Omar Visintin',
#  'Oskar Eriksson',
#  'Oslo bid for the 2022 Winter Olympics',
#  'Pakistan at the 2022 Winter Olympics',
#  'Park Jang-hyuk',
#  'Pascal Dion',
#  'Patrick Roest',
#  'Patrik Rybár',
#  'Pavel Karnaukhov',
#  'Pavol Regenda',
#  'Peder Kongshaug',
#  'Peru at the 2022 Winter Olympics',
#  'Peter Cehlárik',
#  'Peter Prevc',
#  'Peter Schlickenrieder',
#  'Peter Zuzin',
#  'Peter Čerešňák',
#  'Petra Jászapáti',
#  'Petra Nieminen',
#  'Petra Vlhová',
#  'Petteri Lindbohm',
#  'Philippines at the 2022 Winter Olympics',
#  'Pietro Sighel',
#  'Poland at the 2022 Winter Olympics',
#  'Portugal at the 2022 Winter Olympics',
#  'Puerto Rico at the 2022 Winter Olympics',
#  'Pål Golberg',
#  'Qi Guangpu',
#  'Qu Chunyu',
#  'Quentin Fillon Maillet',
#  'Queralt Castellet',
#  'Rachael Karker',
#  'Rasmus Windingstad',
#  'Rasmus Wranå',
#  'Rebecca Johnston',
#  'Ren Ziwei',
#  'Renata Fast',
#  'Richard Jouve',
#  'Riku Miura',
#  'Roberts Plūme (luger)',
#  'Rock (ski course)',
#  'Romania at the 2022 Winter Olympics',
#  'Ronja Savolainen',
#  'Ross Whyte',
#  'Ruslan Zakharov',
#  'Russian Olympic Committee athletes at the 2022 Winter Olympics',
#  'Ryan Cochran-Siegle',
#  'Ryan Regez',
#  'Ryan Sommer',
#  'Ryuichi Kihara',
#  'Ryōta Yamamoto',
#  'Ryōyū Kobayashi',
#  'Said Karimulla Khalili',
#  'Sakari Manninen',
#  'Saku Mäenalanen',
#  'Sami Vatanen',
#  'Samuel Kňažko',
#  'Samuel Takáč',
#  'San Marino at the 2022 Winter Olympics',
#  'Sandra Näslund',
#  'Sanni Hakala',
#  'Sanni Rantala',
#  'Sanni Vanhanen',
#  'Sara Hector',
#  'Sara McManus',
#  'Sarah Fillier',
#  'Sarah Nurse',
#  'Sascha Benecken',
#  'Satsuki Fujisawa',
#  'Saudi Arabia at the 2022 Winter Olympics',
#  'Savannah Harmon',
#  'Scotty James',
#  'Sebastian Foss-Solevåg',
#  'Selma Poutsma',
#  'Semion Elistratov',
#  'Sena Tomita',
#  'Seo Whi-min',
#  'Serbia at the 2022 Winter Olympics',
#  'Sergei Andronov',
#  'Sergei Plotnikov',
#  'Sergei Telegin',
#  'Sergey Ridzik',
#  'Sergey Trofimov',
#  'Sergey Ustiugov',
#  'Shaoang Liu',
#  'Shaolin Sándor Liu',
#  'Shijingshan, Beijing',
#  'Shoma Uno',
#  'Short track speed skating at the 2022 Winter Olympics',
#  'Short track speed skating at the 2022 Winter Olympics – Qualification',
#  'Simen Hegstad Krüger',
#  'Simon Desthieux',
#  'Sini Karjalainen',
#  'Skeleton at the 2022 Winter Olympics',
#  'Skeleton at the 2022 Winter Olympics – Qualification',
#  'Ski jumping at the 2022 Winter Olympics',
#  'Ski jumping at the 2022 Winter Olympics – Qualification',
#  'Slava Voynov',
#  'Slovakia at the 2022 Winter Olympics',
#  'Slovenia at the 2022 Winter Olympics',
#  'Snow Ruyi National Ski Jumping Centre',
#  'Snowboarding at the 2022 Winter Olympics',
#  'Snowboarding at the 2022 Winter Olympics – Qualification',
#  'Sofia Goggia',
#  'Sofia Mabergs',
#  'Sofianna Sundelin',
#  'Sofie Krehl',
#  'South Korea at the 2022 Winter Olympics',
#  'Spain at the 2022 Winter Olympics',
#  'Speed skating at the 2022 Winter Olympics',
#  'Speed skating at the 2022 Winter Olympics – Qualification',
#  'Stanislav Galiev',
#  'Stefan Brennsteiner',
#  'Stefan Kraft',
#  'Stefania Constantini',
#  'Stephan Leyhe',
#  'Steven Dubois',
#  'Stockholm bid for the 2022 Winter Olympics',
#  'Sturla Holm Lægreid',
#  'Su Yiming',
#  'Sui Wenjing',
#  'Susanna Tapani',
#  'Suzanne Schulting',
#  'Sverre Lunde Pedersen',
#  'Svetlana Mironova (biathlete)',
#  'Sweden at the 2022 Winter Olympics',
#  'Switzerland at the 2022 Winter Olympics',
#  'Sylvia Hoffman',
#  'Tanja Niskanen',
#  'Tarjei Bø',
#  'Tatiana Ivanova',
#  'Tatiana Sorina',
#  'Teemu Hartikainen',
#  'Template:Bids for the 2022 Winter Olympics',
#  'Teresa Stadlober',
#  'Tess Coady',
#  'Tess Ledeux',
#  'Thailand at the 2022 Winter Olympics',
#  'Thea Louise Stjernesund',
#  'Therese Johaug',
#  'Thomas Krol',
#  'Thomas Steu',
#  'Thorsten Margis',
#  'Tim Koleto',
#  'Tim Mastnak',
#  'Timi Zajc',
#  'Timoleon Tsourekas',
#  'Timon Haugan',
#  'Timor Leste at the 2022 Winter Olympics',
#  'Timur Bilyalov',
#  'Tiril Eckhoff',
#  'Tobias Arlt',
#  'Tobias Wendl',
#  'Tommaso Dotti',
#  'Tomáš Jurčo',
#  'Toni Eggert',
#  'Toni Rajala',
#  'Trinidad and Tobago at the 2022 Winter Olympics',
#  'Turkey at the 2022 Winter Olympics',
#  'Ukraine at the 2022 Winter Olympics',
#  'Uliana Nigmatullina',
#  'United States at the 2022 Winter Olympics',
#  'Urša Bogataj',
#  'Uzbekistan at the 2022 Winter Olympics',
#  'Vadim Shipachyov',
#  'Valtteri Filppula',
#  'Valtteri Kemiläinen',
#  'Valérie Maltais',
#  'Vanessa Hinz',
#  'Vanessa Voigt',
#  'Venues of the 2022 Winter Olympics and Paralympics',
#  'Veronika Stepanova',
#  'Vetle Sjåstad Christiansen',
#  'Vic Wild',
#  'Vicky Wright',
#  'Victoria Carl',
#  'Victoria Sinitsina',
#  'Viivi Vainikka',
#  'Ville Pokka',
#  'Vincent Zhou',
#  'Vinzenz Geiger',
#  'Virgin Islands at the 2022 Winter Olympics',
#  'Vladimir Morozov (figure skater)',
#  'Vladimir Tkachyov (ice hockey, born 1993)',
#  'Wakaba Higuchi',
#  'Walter Wallberg',
#  'Wataru Morishige',
#  'Wendy Holdener',
#  'Wolfgang Kindl',
#  'World and Olympic records set at the 2022 Winter Olympics',
#  'Wu Dajing',
#  'Wukesong Arena',
#  'Xandra Velzeboer',
#  'Xu Mengtao',
#  'Yan Wengang',
#  'Yanqing National Alpine Skiing Centre',
#  'Yanqing National Sliding Centre',
#  'Yara van Kerkhof',
#  'Yoshito Watabe',
#  'Yuliya Stupak',
#  'Yuma Kagiyama',
#  'Yumi Suzuki',
#  'Yuri Confortola',
#  'Yurika Yoshida',
#  'Zachary Donohue',
#  'Zhang Yuting',
#  'Zoi Sadowski-Synnott',
#  'Zsófia Kónya',
#  'Éliot Grondin',
#  'Émilien Jacquelin',
#  'Šimon Nemec',
#  'Žan Kranjec'}

# %% [markdown]
# ## 2. Chunk documents
#
# Now that we have our reference documents, we need to prepare them for search.
#
# Because GPT can only read a limited amount of text at once, we'll split each document into chunks short enough to be read.
#
# For this specific example on Wikipedia articles, we'll:
# - Discard less relevant-looking sections like External Links and Footnotes
# - Clean up the text by removing reference tags (e.g., <ref>), whitespace, and super short sections
# - Split each article into sections
# - Prepend titles and subtitles to each section's text, to help GPT understand the context
# - If a section is long (say, > 1,600 tokens), we'll recursively split it into smaller sections, trying to split along semantic boundaries like paragraphs

# %%
# define functions to split Wikipedia pages into sections

SECTIONS_TO_IGNORE = [
    "See also",
    "References",
    "External links",
    "Further reading",
    "Footnotes",
    "Bibliography",
    "Sources",
    "Citations",
    "Literature",
    "Footnotes",
    "Notes and references",
    "Photo gallery",
    "Works cited",
    "Photos",
    "Gallery",
    "Notes",
    "References and sources",
    "References and notes",
]


def all_subsections_from_section(
    section: mwparserfromhell.wikicode.Wikicode,
    parent_titles: list[str],
    sections_to_ignore: set[str],
) -> list[tuple[list[str], str]]:
    """
    From a Wikipedia section, return a flattened list of all nested subsections.
    Each subsection is a tuple, where:
        - the first element is a list of parent subtitles, starting with the page title
        - the second element is the text of the subsection (but not any children)
    """
    headings = [str(h) for h in section.filter_headings()]
    title = headings[0]
    if title.strip("=" + " ") in sections_to_ignore:
        # ^wiki headings are wrapped like "== Heading =="
        return []
    titles = parent_titles + [title]
    full_text = str(section)
    section_text = full_text.split(title)[1]
    if len(headings) == 1:
        return [(titles, section_text)]
    else:
        first_subtitle = headings[1]
        section_text = section_text.split(first_subtitle)[0]
        results = [(titles, section_text)]
        for subsection in section.get_sections(levels=[len(titles) + 1]):
            results.extend(all_subsections_from_section(subsection, titles, sections_to_ignore))
        return results


def all_subsections_from_title(
    title: str,
    sections_to_ignore: set[str] = SECTIONS_TO_IGNORE,
    site_name: str = WIKI_SITE,
) -> list[tuple[list[str], str]]:
    """From a Wikipedia page title, return a flattened list of all nested subsections.
    Each subsection is a tuple, where:
        - the first element is a list of parent subtitles, starting with the page title
        - the second element is the text of the subsection (but not any children)
    """
    site = mwclient.Site(site_name)
    page = site.pages[title]
    text = page.text()
    parsed_text = mwparserfromhell.parse(text)
    headings = [str(h) for h in parsed_text.filter_headings()]
    if headings:
        summary_text = str(parsed_text).split(headings[0])[0]
    else:
        summary_text = str(parsed_text)
    results = [([title], summary_text)]
    for subsection in parsed_text.get_sections(levels=[2]):
        results.extend(all_subsections_from_section(subsection, [title], sections_to_ignore))
    return results

# %%
tl = list(titles)
tl
# Out:
# ['Figure skating at the 2022 Winter Olympics',
#  'Greece at the 2022 Winter Olympics',
#  'Elīza Tīruma',
#  'Ross Whyte',
#  'Kim A-lang',
#  'Lewis Irving',
#  'Ebba Andersson (cross-country skier)',
#  'Sergei Andronov',
#  'Zachary Donohue',
#  '2022 Winter Olympics medal table',
#  'Grace Zumwinkle',
#  'Kerttu Niskanen',
#  'Timon Haugan',
#  'Mark Kondratiuk',
#  'Sanni Rantala',
#  'Nikita Gusev',
#  'Federica Brignone',
#  'Yan Wengang',
#  'Elvira Öberg',
#  'David Wise (freestyle skier)',
#  'Tiril Eckhoff',
#  'Chinese Taipei at the 2022 Winter Olympics',
#  'Jaclyn Narracott',
#  'Alexander Schmid',
#  'Teresa Stadlober',
#  '2022 Winter Olympics torch relay',
#  'Han Yutong',
#  'Bobsleigh at the 2022 Winter Olympics – Qualification',
#  'Elana Meyers Taylor',
#  'Jamaica at the 2022 Winter Olympics',
#  'Mikko Lehtonen (ice hockey, born 1994)',
#  'Yuma Kagiyama',
#  'Francesco Friedrich',
#  'Mathilde Gremaud',
#  'Marc Kennedy',
#  'Madison Chock',
#  'Romania at the 2022 Winter Olympics',
#  'Evan Bates',
#  'Skeleton at the 2022 Winter Olympics',
#  'Thomas Steu',
#  'Juuso Hietanen',
#  'Ikuma Horishima',
#  'Jia Zongyang',
#  'Tim Mastnak',
#  'Angelina Golikova',
#  'Marte Olsbu Røiseland',
#  'Hannah Brandt',
#  'Cross-country skiing at the 2022 Winter Olympics',
#  'Grant Hardie',
#  'Amos Mosaner',
#  'Bulgaria at the 2022 Winter Olympics',
#  'Iran at the 2022 Winter Olympics',
#  'Anna Shcherbakova',
#  'Kelly Pannek',
#  'Hans Christer Holund',
#  'Harri Pesonen',
#  'Toni Rajala',
#  'Teemu Hartikainen',
#  'Freestyle skiing at the 2022 Winter Olympics',
#  'Italy at the 2022 Winter Olympics',
#  'Hanna Öberg',
#  'Iceland at the 2022 Winter Olympics',
#  'Gloria Kotnik',
#  'Claire Thompson (ice hockey)',
#  'Capital Indoor Stadium',
#  'Juraj Slafkovský',
#  'Timi Zajc',
#  'Speed skating at the 2022 Winter Olympics – Qualification',
#  'Peter Zuzin',
#  '2022 Winter Olympics Parade of Nations',
#  'Simen Hegstad Krüger',
#  'Arseni Gritsyuk',
#  'Great Britain at the 2022 Winter Olympics',
#  'Ivan Yakimushkin',
#  'Austria at the 2022 Winter Olympics',
#  '2022 Winter Paralympics Parade of Nations',
#  'Steven Dubois',
#  'Bobsleigh at the 2022 Winter Olympics',
#  'Anastasia Smirnova (freestyle skier)',
#  'Australia at the 2022 Winter Olympics',
#  'Deborah Levi',
#  'Sascha Benecken',
#  'Choi Min-jeong',
#  'Jan Scherrer',
#  'Julia Simon (biathlete)',
#  'Ryan Cochran-Siegle',
#  'Aleksander Aamodt Kilde',
#  'Joey Mantia',
#  'Sebastian Foss-Solevåg',
#  'Valérie Maltais',
#  'Bobby Lammie',
#  'Hong Kong at the 2022 Winter Olympics',
#  'Hilary Knight (ice hockey)',
#  'Ayano Sato (speed skater)',
#  'Sergey Trofimov',
#  'Fabien Claude',
#  'Lithuania at the 2022 Winter Olympics',
#  'Iiro Pakarinen',
#  'Madagascar at the 2022 Winter Olympics',
#  'Agnes Knochenhauer',
#  'Brandon Frazier',
#  'Erin Ambrose',
#  'China at the 2022 Winter Olympics',
#  'Rock (ski course)',
#  'Jordan Pierre-Gilles',
#  'Ville Pokka',
#  'Cassie Sharpe',
#  'Tommaso Dotti',
#  'Beat Feuz',
#  'Mili Smith',
#  'Arianna Valcepina',
#  'Justin Schoenefeld',
#  'Natalya Nepryayeva',
#  'Justin Kripps',
#  'Viivi Vainikka',
#  'India at the 2022 Winter Olympics',
#  'List of athletes not attending the 2022 Winter Olympics due to COVID-19 concerns',
#  'Kim Min-seok (speed skater)',
#  'Marion Thénault',
#  'Eritrea at the 2022 Winter Olympics',
#  'Michal Čajkovský',
#  'Spain at the 2022 Winter Olympics',
#  'Evgenii Klimov',
#  'Estonia at the 2022 Winter Olympics',
#  'Queralt Castellet',
#  'Template:Bids for the 2022 Winter Olympics',
#  'Lena Dürr',
#  'Nikita Katsalapov',
#  'Timoleon Tsourekas',
#  'Maja Dahlqvist',
#  'Snowboarding at the 2022 Winter Olympics',
#  'Ice River (ski course)',
#  'Katharina Huber',
#  'Qi Guangpu',
#  'Leo Komarov',
#  'Omar Visintin',
#  'Jan Hörl',
#  'Isabelle Weidemann',
#  'Lee Seung-hoon',
#  'Eveliina Mäkinen',
#  'Nathan Chen',
#  'Nelli Laitinen',
#  'Tatiana Ivanova',
#  'Emma Maltais',
#  'Megan Nick',
#  'Shaoang Liu',
#  'Martina Valcepina',
#  'Martina Sáblíková',
#  'Rachael Karker',
#  'Maxime Laoun',
#  'Kristin Skaslien',
#  'Jenni Hiirikoski',
#  'Daniela Ulbing',
#  'Li Wenlong (speed skater)',
#  'Joni Mäki',
#  'Brianna Decker',
#  'Xandra Velzeboer',
#  'Noora Tulus',
#  'Caroline Harvey (ice hockey)',
#  'Curling at the 2022 Winter Olympics – Qualification',
#  'Semion Elistratov',
#  'Samuel Takáč',
#  'Alexander Terentyev',
#  'Anton Slepyshev',
#  'Hideaki Nagai',
#  'Sarah Nurse',
#  'Hwang Dae-heon',
#  'Qu Chunyu',
#  'Richard Jouve',
#  'Irene Schouten',
#  'Maria Therese Tviberg',
#  'Vincent Zhou',
#  'Nika Križnar',
#  'Johan Clarey',
#  'Marko Daňo',
#  'Kristián Pospíšil',
#  'Valtteri Filppula',
#  'Nico Porteous',
#  'Sami Vatanen',
#  'France at the 2022 Winter Olympics',
#  'Krista Pärmäkoski',
#  'Patrik Rybár',
#  'Fan Kexin',
#  'Candy Bauer',
#  'Short track speed skating at the 2022 Winter Olympics',
#  'Matthias Mayer',
#  'Skeleton at the 2022 Winter Olympics – Qualification',
#  'Kim Dong-wook (speed skater)',
#  'Ashton Bell',
#  'Jennifer Dodds',
#  'Marie-Philip Poulin',
#  'Ukraine at the 2022 Winter Olympics',
#  'Ruslan Zakharov',
#  'Harri Säteri',
#  'Lviv bid for the 2022 Winter Olympics',
#  'Meeri Räisänen',
#  'Azerbaijan at the 2022 Winter Olympics',
#  'Tess Coady',
#  'Lindsey Jacobellis',
#  'Hannes Björninen',
#  'Saku Mäenalanen',
#  'Toni Eggert',
#  'Francesca Lollobrigida',
#  'Markus Eisenbichler',
#  'Lukas Greiderer',
#  'Ayumu Hirano',
#  'Nikita Nesterov',
#  'Maurice Manificat',
#  'Alex Fiva',
#  'Gabriella Papadakis',
#  'Mona Brorsson',
#  'Michael Matt',
#  'Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games',
#  'Branislav Konrád',
#  'Chinami Yoshida',
#  'Sweden at the 2022 Winter Olympics',
#  'Sandra Näslund',
#  'Oskar Eriksson',
#  'Vetle Sjåstad Christiansen',
#  'Marek Hrivík',
#  'Beijing National Stadium',
#  'Walter Wallberg',
#  'Patrick Roest',
#  'Peru at the 2022 Winter Olympics',
#  'Curling at the 2022 Winter Olympics',
#  'Sarah Fillier',
#  'Canada at the 2022 Winter Olympics',
#  'Petra Jászapáti',
#  'Dawid Kubacki',
#  'Martin Marinčin',
#  'Cyprus at the 2022 Winter Olympics',
#  'Stefan Brennsteiner',
#  'Pietro Sighel',
#  'Cross-country skiing at the 2022 Winter Olympics – Qualification',
#  'Karen Chen',
#  'North Macedonia at the 2022 Winter Olympics',
#  'Armenia at the 2022 Winter Olympics',
#  'Kosovo at the 2022 Winter Olympics',
#  'Johannes Lochner',
#  'Wakaba Higuchi',
#  'Jesper Tjäder',
#  'Tobias Arlt',
#  'Sofia Goggia',
#  'Sui Wenjing',
#  'Cha Min-kyu',
#  'Shijingshan, Beijing',
#  'Jincy Dunne',
#  'Tomáš Jurčo',
#  'Rasmus Wranå',
#  'Henrik Harlaut',
#  'Stanislav Galiev',
#  'Chronological summary of the 2022 Winter Olympics',
#  'Savannah Harmon',
#  'Sofianna Sundelin',
#  'Arianna Fontana',
#  'Ashley Caldwell',
#  'Zhang Yuting',
#  'Chile at the 2022 Winter Olympics',
#  'Zoi Sadowski-Synnott',
#  'Jaelin Kauf',
#  'Antoinette de Jong',
#  'Sakari Manninen',
#  'Bids for the 2022 Winter Olympics',
#  'Justine Braisaz-Bouchet',
#  'Liechtenstein at the 2022 Winter Olympics',
#  'Johannes Høsflot Klæbo',
#  '2021 Pre-Olympic Qualification Event',
#  'Atte Ohtamaa',
#  'Zsófia Kónya',
#  'Artur Kayumov',
#  'United States at the 2022 Winter Olympics',
#  'Axel Jungk',
#  'Clément Parisse',
#  'Alpine skiing at the 2022 Winter Olympics',
#  'Davide Ghiotto',
#  'Federico Pellegrino',
#  'Erin Jackson',
#  'Madison Hubbell',
#  'Michelle Gisin',
#  'Elisa Holopainen',
#  'Peter Prevc',
#  'Belgium at the 2022 Winter Olympics',
#  'Frida Karlsson',
#  'Montenegro at the 2022 Winter Olympics',
#  'Emily Clark (ice hockey)',
#  'Alexander Bolshunov',
#  'Wataru Morishige',
#  'Brianne Jenner',
#  'Charles Hamelin',
#  'Markus Granlund',
#  'Eileen Gu',
#  'Ryan Sommer',
#  'Shaolin Sándor Liu',
#  'Corinne Suter',
#  'Stockholm bid for the 2022 Winter Olympics',
#  'Nordic combined at the 2022 Winter Olympics',
#  'Laura Nolte',
#  '2022 Winter Olympics closing ceremony flag bearers',
#  'Pascal Dion',
#  'Pakistan at the 2022 Winter Olympics',
#  'Biathlon at the 2022 Winter Olympics – Qualification',
#  'Bing Dwen Dwen and Shuey Rhon Rhon',
#  'Jukka Jalonen',
#  'Netherlands at the 2022 Winter Olympics',
#  'Katharina Liensberger',
#  'Park Jang-hyuk',
#  'Ren Ziwei',
#  'Wolfgang Kindl',
#  'South Korea at the 2022 Winter Olympics',
#  'James Crawford (alpine skier)',
#  'Jocelyne Larocque',
#  'Ecuador at the 2022 Winter Olympics',
#  'Chloe Kim',
#  'Georgia at the 2022 Winter Olympics',
#  'Ronja Savolainen',
#  'Ella Shelton',
#  'Matthew Soukup',
#  'Aleksandr Galliamov',
#  'Maxim Tsvetkov',
#  'Malaysia at the 2022 Winter Olympics',
#  'Hailey Duff',
#  'Michela Moioli',
#  'Hanna Huskova',
#  'Miloš Kelemen',
#  'Short track speed skating at the 2022 Winter Olympics – Qualification',
#  'Daniela Maier',
#  'Andorra at the 2022 Winter Olympics',
#  'Anastasia Mishina',
#  'Mélodie Daoust',
#  'Johannes Ludwig',
#  'Martin Gernát',
#  'Kristen Campbell',
#  'Aleksey Chervotkin',
#  'Vanessa Voigt',
#  'Maddie Rooney',
#  'Alessandro Hämmerle',
#  'Mexico at the 2022 Winter Olympics',
#  'Emilia Vesa',
#  'Alexandra Carpenter',
#  'Veronika Stepanova',
#  'Norway at the 2022 Winter Olympics',
#  'Snow Ruyi National Ski Jumping Centre',
#  'Mirjam Puchner',
#  'Misato Komatsubara',
#  'Kotomi Ishizaki',
#  'Kaori Sakamoto',
#  'Mongolia at the 2022 Winter Olympics',
#  'Colby Stevenson',
#  'Linus Straßer',
#  'Trinidad and Tobago at the 2022 Winter Olympics',
#  'Peter Cehlárik',
#  'Bosnia and Herzegovina at the 2022 Winter Olympics',
#  'Victoria Sinitsina',
#  'Mark McMorris',
#  'Tim Koleto',
#  'Malta at the 2022 Winter Olympics',
#  'Niko Ojamäki',
#  'Fabian Wilkens Solheim',
#  'Emil Iversen',
#  'Anna Hasselborg',
#  'China National Convention Center',
#  'Christopher Weber',
#  'Uliana Nigmatullina',
#  'Sverre Lunde Pedersen',
#  'Matthias Sommer',
#  'Hanne Desmet',
#  'Ethan Cepuran',
#  'Svetlana Mironova (biathlete)',
#  'Katharina Truppe',
#  'Samuel Kňažko',
#  'Hungary at the 2022 Winter Olympics',
#  'Ryan Regez',
#  'Big Air Shougang',
#  'Brazil at the 2022 Winter Olympics',
#  'Cam Stones',
#  'List of 2022 Winter Olympics medal winners',
#  'Tanja Niskanen',
#  'Stefan Kraft',
#  'Christopher Lillis',
#  'Russian Olympic Committee athletes at the 2022 Winter Olympics',
#  'Kokomo Murase',
#  'Hayley Scamurra',
#  'Yanqing National Sliding Centre',
#  'Therese Johaug',
#  'Sylvia Hoffman',
#  'Emery Lehman',
#  'Mathieu Faivre',
#  'Lee Yu-bin',
#  'Katherine Sauerbrey',
#  'Sergey Ridzik',
#  'Han Cong',
#  'Šimon Nemec',
#  'Nadia Delago',
#  'Sini Karjalainen',
#  'Abigail Strate',
#  'Satsuki Fujisawa',
#  'Mislav Rosandić',
#  'Laura Stacey',
#  'Alexandra Trusova',
#  'Ireland at the 2022 Winter Olympics',
#  'Alexander Yelesin',
#  'Alex Ferreira',
#  'Petra Vlhová',
#  'Vladimir Morozov (figure skater)',
#  'Wukesong Arena',
#  'Ivanie Blondin',
#  'Dominik Fischnaller',
#  'Sara McManus',
#  'Karl Geiger',
#  'Virgin Islands at the 2022 Winter Olympics',
#  'Concerns and controversies at the 2022 Winter Olympics',
#  'Luge at the 2022 Winter Olympics – Qualification',
#  'Kim Boutin',
#  'Lee Stecklein',
#  'Victoria Carl',
#  'Mikhail Grigorenko',
#  'Yurika Yoshida',
#  'Kaillie Humphries',
#  'Almaty bid for the 2022 Winter Olympics',
#  'San Marino at the 2022 Winter Olympics',
#  'Irina Avvakumova',
#  'Riku Miura',
#  'Matej Tomek',
#  'Mariama Jamanka',
#  'Ben Coakwell',
#  'Sanni Hakala',
#  'Ester Ledecká',
#  'Vladimir Tkachyov (ice hockey, born 1993)',
#  'Egor Yakovlev',
#  'Peter Čerešňák',
#  'Amanda Kessel',
#  'Jenniina Nylund',
#  'Ann-Renée Desbiens',
#  'Slovakia at the 2022 Winter Olympics',
#  'Hallgeir Engebråten',
#  'Erik Valnes',
#  'Mārtiņš Bots',
#  'Lebanon at the 2022 Winter Olympics',
#  'Niklas Edin',
#  'Moldova at the 2022 Winter Olympics',
#  'Jill Saulnier',
#  'Tess Ledeux',
#  'Alexander Nikishin',
#  'Christian Rasp',
#  'Tatiana Sorina',
#  'Sofia Mabergs',
#  'Poland at the 2022 Winter Olympics',
#  'Katharina Hennig',
#  'Alexander Samonov',
#  'Anton Smolski',
#  'Argentina at the 2022 Winter Olympics',
#  'Alexander Schüller',
#  'Franziska Preuß',
#  'Portugal at the 2022 Winter Olympics',
#  'Iivo Niskanen',
#  'Lorenz Koller',
#  'Sofie Krehl',
#  'Marco Odermatt',
#  'Abby Roque',
#  'Benjamin Karl',
#  'Tobias Wendl',
#  'Morocco at the 2022 Winter Olympics',
#  'Marek Ďaloga',
#  'Ireen Wüst',
#  'Michal Krištof',
#  'Konstantin Ivliev',
#  'Kwak Yoon-gy',
#  '128th IOC Session',
#  'Yuri Confortola',
#  'Pavol Regenda',
#  '2022 Winter Olympics closing ceremony',
#  'Suzanne Schulting',
#  'Renata Fast',
#  'Fanny Smith',
#  'Megan Bozek',
#  '2022 Winter Paralympics medal table',
#  'Kendall Coyne Schofield',
#  'Kelly Sildaru',
#  'Luge at the 2022 Winter Olympics',
#  'Manuel Faißt',
#  'Luxembourg at the 2022 Winter Olympics',
#  'Saudi Arabia at the 2022 Winter Olympics',
#  '2022 Winter Paralympics opening ceremony',
#  'Hammy McMillan Jr.',
#  'Irma Makhinia',
#  'Marielle Thompson',
#  'Éliot Grondin',
#  'Timor Leste at the 2022 Winter Olympics',
#  'Chronological summary of the 2022 Winter Paralympics',
#  'Ivan Fedotov',
#  'Libor Hudáček',
#  'Nigeria at the 2022 Winter Olympics',
#  'Cene Prevc',
#  'Monaco at the 2022 Winter Olympics',
#  'Sergei Telegin',
#  'Shoma Uno',
#  'Susanna Tapani',
#  'Christopher Grotheer',
#  'Sergei Plotnikov',
#  'Freestyle skiing at the 2022 Winter Olympics – Qualification',
#  'Vinzenz Geiger',
#  'Danil Sadreev',
#  'Sanni Vanhanen',
#  'Petteri Lindbohm',
#  'Bolivia at the 2022 Winter Olympics',
#  '2021 Canadian Olympic Curling Trials',
#  'Jørgen Graabak',
#  'Bart Swings',
#  'Dani Cameranesi',
#  'Jonna Sundling',
#  'Brett Gallant',
#  'Belarus at the 2022 Winter Olympics',
#  'Abbey Murphy',
#  'Turkey at the 2022 Winter Olympics',
#  'Anaïs Chevalier-Bouchet',
#  '2022 Winter Paralympics closing ceremony',
#  'Alex Hall (skier)',
#  'Ryōta Yamamoto',
#  'Alexander Loginov (biathlon)',
#  'Beijing National Indoor Stadium',
#  'Biathlon at the 2022 Winter Olympics',
#  'Joonas Nättinen',
#  '2022 Winter Paralympics torch relay',
#  'Philippines at the 2022 Winter Olympics',
#  'Sturla Holm Lægreid',
#  'Chloé Trespeuch',
#  'Wu Dajing',
#  'Christine de Bruin',
#  'Julian Rauchfuß',
#  'Hannah Neise',
#  'Selma Poutsma',
#  'Figure skating at the 2022 Winter Olympics – Qualification',
#  'Vanessa Hinz',
#  'Speed skating at the 2022 Winter Olympics',
#  'Mackenzie Boyd-Clowes',
#  'Marijke Groenewoud',
#  '2022 Winter Paralympics',
#  'Jessie Diggins',
#  'Martin Ponsiluoma',
#  'Nils van der Poel',
#  'Craig Ramsay',
#  'Artyom Minulin',
#  "Ice hockey at the 2022 Winter Olympics – Women's qualification",
#  'Minttu Tuominen',
#  'Daniel Huber (ski jumper)',
#  'Magnus Nedregotten',
#  'Michelle Karvinen',
#  'World and Olympic records set at the 2022 Winter Olympics',
#  'Germany at the 2022 Winter Olympics',
#  'Eric Frenzel',
#  'Miha Fontaine',
#  'Thailand at the 2022 Winter Olympics',
#  'Marius Lindvik',
#  'Damir Sharipzyanov',
#  'Ella Viitasuo',
#  'Jamie Lee Rattray',
#  'Pål Golberg',
#  'Florian Bauer',
#  'Finland at the 2022 Winter Olympics',
#  'Ski jumping at the 2022 Winter Olympics – Qualification',
#  'Dmitri Voronkov',
#  'Alexa Knierim',
#  'List of 2022 Winter Paralympics medal winners',
#  'Yanqing National Alpine Skiing Centre',
#  'Espen Andersen (skier, born 1993)',
#  'Denmark at the 2022 Winter Olympics',
#  'Uzbekistan at the 2022 Winter Olympics',
#  'Sara Hector',
#  'Akito Watabe',
#  'Irina Kazakevich',
#  'Seo Whi-min',
#  '2022 Winter Olympics opening ceremony',
#  'Almida de Val',
#  'Brad Gushue',
#  'Ghana at the 2022 Winter Olympics',
#  'Beijing bid for the 2022 Winter Olympics',
#  'Urša Bogataj',
#  'Valtteri Kemiläinen',
#  'Vic Wild',
#  'Lara Gut-Behrami',
#  "Meryeta O'Dine",
#  'Miho Takagi (speed skater)',
#  'Geoff Walker (curler)',
#  'Kjeld Nuis',
#  'Peter Schlickenrieder',
#  'Yara van Kerkhof',
#  'Ryōyū Kobayashi',
#  'Lee June-seo',
#  'Chung Jae-won',
#  'Katharina Schmid',
#  'New Zealand at the 2022 Winter Olympics',
#  'Yoshito Watabe',
#  'Christoffer Sundgren',
#  'Beijing National Speed Skating Oval',
#  'Dorothea Wierer',
#  'Émilien Jacquelin',
#  'Alexandria Loutitt',
#  'Megan Keller',
#  'Puerto Rico at the 2022 Winter Olympics',
#  'Ski jumping at the 2022 Winter Olympics',
#  'Adrián Holešinský',
#  'Ryuichi Kihara',
#  'Andrea Cassinelli',
#  'Xu Mengtao',
#  'Scotty James',
#  'Anna Gasser',
#  'Espen Bjørnstad',
#  'Casey Dawson',
#  'Sena Tomita',
#  'Laurent Dubreuil',
#  'Birk Ruud',
#  'Slava Voynov',
#  'Natalie Geisenberger',
#  'Vicky Wright',
#  'Thorsten Margis',
#  'Simon Desthieux',
#  'Kraków bid for the 2022 Winter Olympics',
#  'Su Yiming',
#  'Quentin Fillon Maillet',
#  'Miloš Roman',
#  'Vadim Shipachyov',
#  '2020–21 figure skating season',
#  'Bruce Mouat',
#  'Clément Noël',
#  '2022 Winter Olympics marketing',
#  'Yuliya Stupak',
#  'Albania at the 2022 Winter Olympics',
#  'Jens Lurås Oftebro',
#  'Marko Anttila',
#  'Beijing National Aquatics Centre',
#  'Johannes Strolz',
#  'Håvard Holmefjord Lorentzen',
#  'Croatia at the 2022 Winter Olympics',
#  'Andrei Chibisov',
#  'Alexandra Burghardt',
#  'Nick Baumgartner',
#  'American Samoa at the 2022 Winter Olympics',
#  'Jesse Compher',
#  'Miro Aaltonen',
#  '2021 Olympic Qualification Event – Curling',
#  'Pavel Karnaukhov',
#  'Venues of the 2022 Winter Olympics and Paralympics',
#  'Timur Bilyalov',
#  'Emma Aicher',
#  'Petra Nieminen',
#  'Switzerland at the 2022 Winter Olympics',
#  'List of 2022 Winter Olympics broadcasters',
#  'Kirill Semyonov',
#  'Serbia at the 2022 Winter Olympics',
#  'Lovro Kos',
#  'Nicole Hensley',
#  'Haiti at the 2022 Winter Olympics',
#  'Oleksandr Abramenko',
#  'Niklas Friman',
#  'Anni Keisala',
#  'Kamila Valieva',
#  'Nana Takagi',
#  'Kyrgyzstan at the 2022 Winter Olympics',
#  'Wendy Holdener',
#  'Kazakhstan at the 2022 Winter Olympics',
#  'Gao Tingyu',
#  'Emerance Maschmeyer',
#  'Jutta Leerdam',
#  'Madeleine Egle',
#  'Nordic combined at the 2022 Winter Olympics – Qualification',
#  'Roberts Plūme (luger)',
#  'Stephan Leyhe',
#  'Snowboarding at the 2022 Winter Olympics – Qualification',
#  'Kristina Reztsova',
#  'Juho Olkinuora',
#  'Mikaël Kingsbury',
#  'Hugo Lapalus',
#  'Linn Persson',
#  'Julian Schmid (skier)',
#  'Kimberley Bos',
#  '2022 Canadian Mixed Doubles Curling Olympic Trials',
#  'Brittany Bowe',
#  'Max Parrot',
#  'Julia Liikala',
#  'John-Henry Krueger',
#  'Oslo bid for the 2022 Winter Olympics',
#  'Johanna Heldin',
#  'Manuel Fettner',
#  'Mina Fürst Holtmann',
#  'Daniel Magnusson (curler)',
#  'Julia Marino (snowboarder)',
#  'Czech Republic at the 2022 Winter Olympics',
#  'Sergey Ustiugov',
#  'Blayre Turnbull',
#  'Guillaume Cizeron',
#  'Rasmus Windingstad',
#  'Mons Røisland',
#  'Colombia at the 2022 Winter Olympics',
#  'Constantin Schmid',
#  'Thomas Krol',
#  'Anna Berreiter',
#  'Israel at the 2022 Winter Olympics',
#  'Japan at the 2022 Winter Olympics',
#  'Micah Zandee-Hart',
#  'Thea Louise Stjernesund',
#  'COVID-19 cases at the 2022 Winter Olympics and 2022 Winter Paralympics',
#  'Denis Spitsov',
#  'Rebecca Johnston',
#  'Yumi Suzuki',
#  'Peder Kongshaug',
#  '2022 Winter Olympics',
#  'Alex Cavallini',
#  'Daniil Aldoshkin',
#  'Ilya Burov',
#  'Stefania Constantini',
#  'Mark Nichols (curler)',
#  'Evgenia Tarasova',
#  'Nick Goepper',
#  'Eduard Latypov',
#  'Frans Tuohimaa',
#  'Christoph Hafer',
#  'Kristers Aparjods',
#  'Eve Muirhead',
#  'Denise Herrmann-Wick',
#  "Ice hockey at the 2022 Winter Olympics – Men's qualification",
#  'Alpine skiing at the 2022 Winter Olympics – Qualification',
#  'Tarjei Bø',
#  'Said Karimulla Khalili',
#  'Ice hockey at the 2022 Winter Olympics',
#  'Žan Kranjec',
#  'Natalie Spooner',
#  'Johannes Thingnes Bø',
#  'Jakara Anthony',
#  'Cayla Barnes',
#  'Latvia at the 2022 Winter Olympics',
#  'Slovenia at the 2022 Winter Olympics']

# %%
# split pages into sections
# may take ~1 minute per 100 articles
wikipedia_sections = []
for title in tl[:10]:
    wikipedia_sections.extend(all_subsections_from_title(title))
print(f"Found {len(wikipedia_sections)} sections in {len(titles)} pages.")
# Out:
# Found 77 sections in 731 pages.

# %%
wikipedia_sections[0]
# Out:
# (['Figure skating at the 2022 Winter Olympics'],
#  '{{Short description|none}}\n{{Use dmy dates|date=February 2022}}\n{{Infobox Olympic event\n| event   =Figure Skating\n| games   =2022 Winter\n|image = [[Image:Figure skating pictogram.svg|80px]]\n|caption = Figure skating pictogram\n| venue   =[[Capital Indoor Stadium]]\n| dates   =4–20 February\n| num_events =5 (1 men, 1 women, 3 mixed)\n| competitors=148 (74 men, 74 women)\n| nations  =32\n| prev    =[[Figure skating at the 2018 Winter Olympics|2018]]\n| next    =[[Figure skating at the 2026 Winter Olympics|2026]]\n}}\n{{Figure skating at the 2022 Winter Olympics}}\n[[Figure skating at the Olympic Games|Figure skating]] at the [[2022 Winter Olympics]] was held at the [[Capital Indoor Stadium]] in [[Beijing]], [[China]]. The five events took place between 4 and 20 February 2022.<ref name=schedule>{{cite web |url=https://olympics.com/en/beijing-2022/schedule-by-sport/figure-skating/|title=Beijing 2022 Schedule Figure skating|publisher=[[Beijing Organizing Committee for the 2022 Olympic and Paralympic Winter Games|BOCOG]]|access-date=12 August 2021}}</ref>\n\nA total of 144 quota spots were distributed to the sport of figure skating, a decline of four from the 2018 Olympic Winter Games.<ref>{{cite web|url=https://www.isu.org/docman-documents-links-2/2022-beijing/qualification-systems-3/22994-figure-skating-v1-0/file|title=Qualification System for XXIV Olympic Winter Games, Beijing 2022|publisher=[[International Skating Union]]|date=4 December 2019}}</ref><ref name=":0">{{cite web|url=https://stillmed.olympic.org/media/Document%20Library/OlympicOrg/Games/Winter-Games/Games-Beijing-2022-Winter-Olympic-Games/Sports-programme/Beijing-2022-Olympic-programme.pdf|title=Olympic Winter Games Beijing 2022: Event programme and athlete quota|publisher=[[International Olympic Committee]] (IOC)|access-date=5 September 2021}}</ref> From the [[2021–22 figure skating season|2021–22 season]], the [[International Skating Union]] renamed "ladies\' singles" as "women\'s singles".<ref>{{cite web|url=https://www.isu.org/media-centre/press-releases/2021-2/25944-results-of-proposals-in-replacement-of-the-58th-ordinary-isu-congress-2021/file|title=Results of Proposals in Replacement of the 58th Ordinary ISU Congress 2021|publisher=[[International Skating Union]]|date=30 June 2021}}</ref>\n\nA total of five events were contested, one for men, one for women and three mixed.<ref>{{cite web|url=https://stillmed.olympic.org/media/Document%20Library/OlympicOrg/Games/Winter-Games/Games-Beijing-2022-Winter-Olympic-Games/Sports-programme/Beijing-2022-Olympic-programme-en.pdf|title=Official Programme of the Olympic Winter Games Beijing 2022|website=www.olympic.org/|publisher=[[International Olympic Committee]] (IOC)|access-date=13 February 2022}}</ref> \n\n')

# %%
# clean text
def clean_section(section: tuple[list[str], str]) -> tuple[list[str], str]:
    """
    Return a cleaned up section with:
        - <ref>xyz</ref> patterns removed
        - leading/trailing whitespace removed
    """
    titles, text = section
    text = re.sub(r"<ref.*?</ref>", "", text)
    text = text.strip()
    return (titles, text)


wikipedia_sections = [clean_section(ws) for ws in wikipedia_sections]

# filter out short/blank sections
def keep_section(section: tuple[list[str], str]) -> bool:
    """Return True if the section should be kept, False otherwise."""
    titles, text = section
    if len(text) < 16:
        return False
    else:
        return True


original_num_sections = len(wikipedia_sections)
wikipedia_sections = [ws for ws in wikipedia_sections if keep_section(ws)]
print(f"Filtered out {original_num_sections-len(wikipedia_sections)} sections, leaving {len(wikipedia_sections)} sections.")
# Out:
# Filtered out 7 sections, leaving 70 sections.

# %%
# print example data
for ws in wikipedia_sections[:5]:
    print(ws[0])
    display(ws[1][:77] + "...")
    print()
# Out:
# ['Figure skating at the 2022 Winter Olympics']
# '{{Short description|none}}\n{{Use dmy dates|date=February 2022}}\n{{Infobox Oly...'
# ['Figure skating at the 2022 Winter Olympics', '== Qualification ==']
# '{{main|Figure skating at the 2022 Winter Olympics – Qualification}}\nA total o...'
# ['Figure skating at the 2022 Winter Olympics', '==Competition schedule==']
# 'The following is the competition schedule for all five events. Sessions that ...'
# ['Figure skating at the 2022 Winter Olympics', '== Medal summary ==', '=== Medal table ===']
# '{{Medals table\n | caption        = \n | host           =CHN \n | flag_template ...'
# ['Figure skating at the 2022 Winter Olympics', '== Medal summary ==', '=== Events ===']
# '{| {{MedalistTable|type=Event|columns=2}}\n|-valign="top"\n| Men\'s singles<br/>...'

# %% [markdown]
# Next, we'll recursively split long sections into smaller sections.
#
# There's no perfect recipe for splitting text into sections.
#
# Some tradeoffs include:
# - Longer sections may be better for questions that require more context
# - Longer sections may be worse for retrieval, as they may have more topics muddled together
# - Shorter sections are better for reducing costs (which are proportional to the number of tokens)
# - Shorter sections allow more sections to be retrieved, which may help with recall
# - Overlapping sections may help prevent answers from being cut by section boundaries
#
# Here, we'll use a simple approach and limit sections to 1,600 tokens each, recursively halving any sections that are too long. To avoid cutting in the middle of useful sentences, we'll split along paragraph boundaries when possible.

# %%
GPT_MODEL = "gpt-3.5-turbo"  # only matters insofar as it selects which tokenizer to use


def num_tokens(text: str, model: str = GPT_MODEL) -> int:
    """Return the number of tokens in a string."""
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))


def halved_by_delimiter(string: str, delimiter: str = "\n") -> list[str, str]:
    """Split a string in two, on a delimiter, trying to balance tokens on each side."""
    chunks = string.split(delimiter)
    if len(chunks) == 1:
        return [string, ""]  # no delimiter found
    elif len(chunks) == 2:
        return chunks  # no need to search for halfway point
    else:
        total_tokens = num_tokens(string)
        halfway = total_tokens // 2
        best_diff = halfway
        for i, chunk in enumerate(chunks):
            left = delimiter.join(chunks[: i + 1])
            left_tokens = num_tokens(left)
            diff = abs(halfway - left_tokens)
            if diff >= best_diff:
                break
            else:
                best_diff = diff
        left = delimiter.join(chunks[:i])
        right = delimiter.join(chunks[i:])
        return [left, right]


def truncated_string(
    string: str,
    model: str,
    max_tokens: int,
    print_warning: bool = True,
) -> str:
    """Truncate a string to a maximum number of tokens."""
    encoding = tiktoken.encoding_for_model(model)
    encoded_string = encoding.encode(string)
    truncated_string = encoding.decode(encoded_string[:max_tokens])
    if print_warning and len(encoded_string) > max_tokens:
        print(f"Warning: Truncated string from {len(encoded_string)} tokens to {max_tokens} tokens.")
    return truncated_string


def split_strings_from_subsection(
    subsection: tuple[list[str], str],
    max_tokens: int = 1000,
    model: str = GPT_MODEL,
    max_recursion: int = 5,
) -> list[str]:
    """
    Split a subsection into a list of subsections, each with no more than max_tokens.
    Each subsection is a tuple of parent titles [H1, H2, ...] and text (str).
    """
    titles, text = subsection
    string = "\n\n".join(titles + [text])
    num_tokens_in_string = num_tokens(string)
    # if length is fine, return string
    if num_tokens_in_string <= max_tokens:
        return [string]
    # if recursion hasn't found a split after X iterations, just truncate
    elif max_recursion == 0:
        return [truncated_string(string, model=model, max_tokens=max_tokens)]
    # otherwise, split in half and recurse
    else:
        titles, text = subsection
        for delimiter in ["\n\n", "\n", ". "]:
            left, right = halved_by_delimiter(text, delimiter=delimiter)
            if left == "" or right == "":
                # if either half is empty, retry with a more fine-grained delimiter
                continue
            else:
                # recurse on each half
                results = []
                for half in [left, right]:
                    half_subsection = (titles, half)
                    half_strings = split_strings_from_subsection(
                        half_subsection,
                        max_tokens=max_tokens,
                        model=model,
                        max_recursion=max_recursion - 1,
                    )
                    results.extend(half_strings)
                return results
    # otherwise no split was found, so just truncate (should be very rare)
    return [truncated_string(string, model=model, max_tokens=max_tokens)]

# %%
# split sections into chunks
MAX_TOKENS = 1600
wikipedia_strings = []
for section in wikipedia_sections:
    wikipedia_strings.extend(split_strings_from_subsection(section, max_tokens=MAX_TOKENS))

print(f"{len(wikipedia_sections)} Wikipedia sections split into {len(wikipedia_strings)} strings.")
# Out:
# 70 Wikipedia sections split into 79 strings.

# %%
# print example data
print(wikipedia_strings[70])
# Out:
# Zachary Donohue
#
# == Competitive highlights ==
#
# === With Lamar ===
#
# {| class="wikitable" style="text-align:center"
# |-
# ! style="background-color: #ffdead; " colspan=2 align=center | National
# |-
# ! Event
# ! 07–08 <br>
# |-
# | align=left | [[Eastern Sectional Figure Skating Championships|Eastern Sec.]] || 5th J
# |-
# | colspan=2 align=center | <small> Levels: N = Novice; J = Junior </small>
# |}

# %% [markdown]
# ## 3. Embed document chunks
#
# Now that we've split our library into shorter self-contained strings, we can compute embeddings for each.
#
# (For large embedding jobs, use a script like [api_request_parallel_processor.py](api_request_parallel_processor.py) to parallelize requests while throttling to stay under rate limits.)

# %%
# calculate embeddings
EMBEDDING_MODEL = "text-embedding-ada-002"  # OpenAI's best embeddings as of Apr 2023
BATCH_SIZE = 1000  # you can submit up to 2048 embedding inputs per request

embeddings = []
for batch_start in range(0, len(wikipedia_strings), BATCH_SIZE):
    batch_end = batch_start + BATCH_SIZE
    batch = wikipedia_strings[batch_start:batch_end]
    print(f"Batch {batch_start} to {batch_end-1}")
    response = openai.Embedding.create(model=EMBEDDING_MODEL, input=batch)
    for i, be in enumerate(response["data"]):
        assert i == be["index"]  # double check embeddings are in same order as input
    batch_embeddings = [e["embedding"] for e in response["data"]]
    embeddings.extend(batch_embeddings)

df = pd.DataFrame({"text": wikipedia_strings, "embedding": embeddings})
# Out:
# Batch 0 to 999
# Batch 1000 to 1999
# Batch 2000 to 2999
# Batch 3000 to 3999
# Batch 4000 to 4999
# Batch 5000 to 5999
# Batch 6000 to 6999

# %% [markdown]
# ## 4. Store document chunks and embeddings
#
# Because this example only uses a few thousand strings, we'll store them in a CSV file.
#
# (For larger datasets, use a vector database, which will be more performant.)

# %%
# save document chunks and embeddings

SAVE_PATH = "data/winter_olympics_2022.csv"

df.to_csv(SAVE_PATH, index=False)
